# %% [markdown]
# # NEPAL EARTHQUAKE TWITTER ANALYSIS
#
#
# ### Microblogging sites like Twitter are increasingly being used for aiding relief operations during various mass emergencies. A lot of critical situational information is posted on microblogging sites during disaster events. However, messages posted on microblogging sites often contain rumors and overstated facts. In such situations, identification of factual or fact-checkable tweets, i.e., tweets that report some relevant and verifiable fact (other than sympathy or prayer) is extremely important for effective coordination of post-disaster relief operations. Additionally, cross verification of such critical information is a practical necessity and resource availability. Hence, automated Machine Learning techniques are needed to identify the tweets that talk about the need of resources or availability of resources.

# %% [markdown]
# #### IMPORTING THE LIBRARIES

# %%
import pandas as pd 
import numpy as np              
import seaborn as sns           
import matplotlib.pyplot as plt

# %%
df=pd.read_csv("train.csv")

# %%
df.head(10)
# Out:
#    TweetClass             TweetID  \
# 0           0  591764470197723137
# 1           0  591779538046218240
# 2           0  591728244925210624
# 3           0  591774433926193152
# 4           0  591764472651386882
# 5           0  591751543025569793
# 6           0  591727216267890688
# 7           0  591739000001470464
# 8           0  591753691084038146
# 9           0  591747428358881282
#
#                                            TweetText
# 0  #Nepal #news Adding to Bhutanese Refugees Bhut...
# 1  The massacre of people's movement says peace a...
# 2  I'm lonely maybe you're going to die without c...
# 3  #nepal #news 6 billion collection collection 1...
# 4  #Nepal #news Indian proposal to crash airport ...
# 5  God also ran away for money after the poor lis...
# 6                   Someone feels like a tile to see
# 7   The boys began to write English passage. I - taw
# 8  I will not go away it's not going to be broken...
# 9                                         Gaurab Sir

# %%
df.tail(10)
# Out:
#        TweetClass             TweetID  \
# 18223           2  592684009563549696
# 18224           2  592683279188361217
# 18225           2  592694344655699968
# 18226           2  592697492422144000
# 18227           2  592696857815572481
# 18228           2  592697535271174145
# 18229           2  592697135390416899
# 18230           2  592698989507715075
# 18231           1    5644654646545646
# 18232           2     543533654345435
#
#                                                TweetText
# 18223  Earthquake Nepal Indian Army takes up major re...
# 18224  National disaster helpline number made operati...
# 18225  Israel sends humanitarian aid to Nepal In the ...
# 18226  #UttarPradesh \\u200bgovt sends buses to #Nepa...
# 18227  Sikh organization to send lakh food packets to...
# 18228  #Earthquake in #Nepal #GoldenTemple Temple to ...
# 18229  Nepal Earthquake Eerts from AIIMS Safdarjung H...
# 18230  UNHCR rushes plastic sheeting and solar-powere...
# 18231  Urgent medical need food water needed medicine...
# 18232               Available plenty medicine food water

# %%
df.shape
# Out:
# (18233, 3)

# %%
df.describe()
# Out:
#          TweetClass       TweetID
# count  18233.000000  1.823300e+04
# mean       0.083749  5.923055e+17
# std        0.386754  6.178048e+15
# min        0.000000  5.435337e+14
# 25%        0.000000  5.921631e+17
# 50%        0.000000  5.925189e+17
# 75%        0.000000  5.926002e+17
# max        2.000000  5.927001e+17

# %%
df.columns
# Out:
# Index(['TweetClass', 'TweetID', 'TweetText'], dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 18233 entries, 0 to 18232
# Data columns (total 3 columns):
# TweetClass    18233 non-null int64
# TweetID       18233 non-null int64
# TweetText     18224 non-null object
# dtypes: int64(2), object(1)
# memory usage: 427.4+ KB

# %%
df['TweetClass'].value_counts()
# Out:
# 0    17370
# 2      664
# 1      199
# Name: TweetClass, dtype: int64

# %%
#Checking for null values
df.isnull()
# Out:
#        TweetClass  TweetID  TweetText
# 0           False    False      False
# 1           False    False      False
# 2           False    False      False
# 3           False    False      False
# 4           False    False      False
# 5           False    False      False
# 6           False    False      False
# 7           False    False      False
# 8           False    False      False
# 9           False    False      False
# 10          False    False      False
# 11          False    False      False
# 12          False    False      False
# 13          False    False      False
# 14          False    False      False
# 15          False    False      False
# 16          False    False      False
# 17          False    False      False
# 18          False    False      False
# 19          False    False      False
# 20          False    False      False
# 21          False    False      False
# 22          False    False      False
# 23          False    False      False
# 24          False    False      False
# 25          False    False      False
# 26          False    False      False
# 27          False    False      False
# 28          False    False      False
# 29          False    False      False
# ...           ...      ...        ...
# 18203       False    False      False
# 18204       False    False      False
# 18205       False    False      False
# 18206       False    False      False
# 18207       False    False      False
# 18208       False    False      False
# 18209       False    False      False
# 18210       False    False      False
# 18211       False    False      False
# 18212       False    False      False
# 18213       False    False      False
# 18214       False    False      False
# 18215       False    False      False
# 18216       False    False      False
# 18217       False    False      False
# 18218       False    False      False
# 18219       False    False      False
# 18220       False    False      False
# 18221       False    False      False
# 18222       False    False      False
# 18223       False    False      False
# 18224       False    False      False
# 18225       False    False      False
# 18226       False    False      False
# 18227       False    False      False
# 18228       False    False      False
# 18229       False    False      False
# 18230       False    False      False
# 18231       False    False      False
# 18232       False    False      False
#
# [18233 rows x 3 columns]

# %%
df.isnull().sum()
# Out:
# TweetClass    0
# TweetID       0
# TweetText     9
# dtype: int64

# %%
sns.barplot( x = df['TweetClass'].value_counts() , y = ["Non_relevant", 'Offer','Need'])

# %%
df.duplicated()
# Out:
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
# 5        False
# 6        False
# 7        False
# 8        False
# 9        False
# 10       False
# 11       False
# 12       False
# 13       False
# 14       False
# 15       False
# 16       False
# 17       False
# 18       False
# 19       False
# 20       False
# 21       False
# 22       False
# 23       False
# 24       False
# 25       False
# 26       False
# 27       False
# 28       False
# 29       False
#          ...
# 18203    False
# 18204    False
# 18205    False
# 18206    False
# 18207    False
# 18208    False
# 18209    False
# 18210    False
# 18211    False
# 18212    False
# 18213    False
# 18214    False
# 18215    False
# 18216    False
# 18217    False
# 18218    False
# 18219    False
# 18220    False
# 18221    False
# 18222    False
# 18223    False
# 18224    False
# 18225    False
# 18226    False
# 18227    False
# 18228    False
# 18229    False
# 18230    False
# 18231    False
# 18232    False
# Length: 18233, dtype: bool

# %%
dupli=df.duplicated()
dupli.value_counts()
# Out:
# False    18233
# dtype: int64

# %%
new_df=df.drop_duplicates()
new_df.describe()
# Out:
#          TweetClass       TweetID
# count  18233.000000  1.823300e+04
# mean       0.083749  5.923055e+17
# std        0.386754  6.178048e+15
# min        0.000000  5.435337e+14
# 25%        0.000000  5.921631e+17
# 50%        0.000000  5.925189e+17
# 75%        0.000000  5.926002e+17
# max        2.000000  5.927001e+17

# %%
sns.kdeplot(data = df.TweetClass , color = 'blue' , shade = True)

# %%
irrelevant_df=df[df['TweetClass']==0]
need_df=df[df['TweetClass']==1]
available_df=df[df['TweetClass']==2]
print(irrelevant_df.shape)
print(need_df.shape)
print(available_df.shape)
# Out:
# (17370, 3)
# (199, 3)
# (664, 3)

# %%
need_df.head(10)
# Out:
#        TweetClass             TweetID  \
# 17370           1  591922042481479680
# 17371           1  591979790627840000
# 17372           1  591985311665684480
# 17373           1  591989264256106499
# 17374           1  591987020924260354
# 17375           1  591988336090173440
# 17376           1  591985786880327682
# 17377           1  591992896485597184
# 17378           1  591995052169105408
# 17379           1  591996373869826048
#
#                                                TweetText
# 17370   Nepal seeks mobile medical assistance from India
# 17371  Nepalis r w/o water &amp electricity Water is ...
# 17372  The wounded and untimely families need to take...
# 17373  they are in search of blood donors for the peo...
# 17374  Walked all around central &amp old KTM.Shops o...
# 17375  Food First Aid &amp Tents would be the princip...
# 17376  RightWingers of ALL religions must keep away f...
# 17377  Lac Rail Neer bottles is not what Nepal needs ...
# 17378  Need more resources and personnel from Army fo...
# 17379  India could surely despatch -4 Field Ambulance...

# %%
available_df.head(10)
# Out:
#        TweetClass             TweetID  \
# 17568           2  591915875638325248
# 17569           2  591933551798419456
# 17570           2  591939270673182721
# 17571           2  591968116919410690
# 17572           2  591974898139987968
# 17573           2  591978159102435328
# 17574           2  591978910713139202
# 17575           2  591975873009582080
# 17576           2  591976580232052736
# 17577           2  591975888494854145
#
#                                                TweetText
# 17568  Indian Prime Minister Narendra Modi has announ...
# 17569  Phone from NTC does not take money when you ca...
# 17570  India has sent 5 helicopters for relief and re...
# 17571  NDRF personnel relief material was sent to Nep...
# 17572  #SriLanka to fly emergency medical help food t...
# 17573  · Hospital Fire Brigade and Blood Banks Name T...
# 17574  Just electricity is available at Shankhamul ar...
# 17575  Indian Railways Ministry sending one lakh Rail...
# 17576  Amount of supplies may be used for more than d...
# 17577  Haryana govt to airlift 000 food packets tomor...

# %%
irrelevant_df.head(10)
# Out:
#    TweetClass             TweetID  \
# 0           0  591764470197723137
# 1           0  591779538046218240
# 2           0  591728244925210624
# 3           0  591774433926193152
# 4           0  591764472651386882
# 5           0  591751543025569793
# 6           0  591727216267890688
# 7           0  591739000001470464
# 8           0  591753691084038146
# 9           0  591747428358881282
#
#                                            TweetText
# 0  #Nepal #news Adding to Bhutanese Refugees Bhut...
# 1  The massacre of people's movement says peace a...
# 2  I'm lonely maybe you're going to die without c...
# 3  #nepal #news 6 billion collection collection 1...
# 4  #Nepal #news Indian proposal to crash airport ...
# 5  God also ran away for money after the poor lis...
# 6                   Someone feels like a tile to see
# 7   The boys began to write English passage. I - taw
# 8  I will not go away it's not going to be broken...
# 9                                         Gaurab Sir

# %%
from sklearn.feature_extraction.text import CountVectorizer
irrelevant_vect=CountVectorizer(stop_words='english')
need_vect=CountVectorizer(stop_words='english')
available_vect=CountVectorizer(stop_words='english')
irrelevant_dtm=irrelevant_vect.fit_transform(irrelevant_df['TweetText'].values.astype('U'))
need_dtm=need_vect.fit_transform(need_df['TweetText'].values.astype('U'))
available_dtm=available_vect.fit_transform(available_df['TweetText'].values.astype('U'))

# %%
irrelevant_word=irrelevant_vect.get_feature_names()
irrelevant_freqs=irrelevant_dtm.sum(axis=0).A1
irrelevant_result=dict(zip(irrelevant_word,irrelevant_freqs))
print(len(irrelevant_word))
# Out:
# 16451

# %%
need_word=need_vect.get_feature_names()
need_freqs=need_dtm.sum(axis=0).A1
need_result=dict(zip(need_word,need_freqs))
print(len(need_word))
# Out:
# 755

# %%
available_word=available_vect.get_feature_names()
available_freqs=available_dtm.sum(axis=0).A1
available_result=dict(zip(available_word,available_freqs))
print(len(available_word))
# Out:
# 1581

# %%
from wordcloud import WordCloud

# %%
wordcloud=WordCloud(background_color='black',
                   width=1600,
                   height=800).generate_from_frequencies(irrelevant_result)
fig=plt.figure(figsize=(30,20))
plt.imshow(wordcloud)
plt.axis("off")
fig.savefig("irrelevant_wordcloud.png")
plt.show()

# %%
wordcloud=WordCloud(background_color='white',
                   width=1600,
                   height=800).generate_from_frequencies(need_result)
fig=plt.figure(figsize=(30,20))
plt.imshow(wordcloud)
plt.axis("off")
fig.savefig("need_wordcloud.png")
plt.show()

# %%
wordcloud=WordCloud(background_color='black',
                   width=1600,
                   height=800).generate_from_frequencies(available_result)
fig=plt.figure(figsize=(30,20))
plt.imshow(wordcloud)
plt.axis("off")
fig.savefig("available_wordcloud.png")
plt.show()

# %%
print(need_result)
# Out:
# {'000': 4, '13': 2, '18': 3, '1mn': 2, '24': 1, '26': 3, '36': 3, '39': 3, '3novices': 1, '500': 1, '84500': 4, '900': 2, '99': 1, '9u': 1, 'able': 3, 'acc': 1, 'access': 2, 'acute': 1, 'address': 1, 'affected': 3, 'aftershocks': 4, 'agency': 2, 'aid': 10, 'air': 1, 'aircraft': 2, 'airport': 1, 'alive': 1, 'ambulance': 1, 'ambulances': 1, 'amp': 26, 'ampeployment': 1, 'anaesthetists': 1, 'analgesic': 1, 'announce': 1, 'announced': 1, 'announicing': 2, 'antibiotics': 1, 'anybody': 1, 'apparently': 2, 'appeal': 4, 'area': 2, 'areas': 2, 'army': 1, 'arrange': 1, 'art': 1, 'asap': 1, 'ask': 1, 'asked': 1, 'assistance': 6, 'aswell': 1, 'attack': 1, 'avalanche': 1, 'away': 2, 'ayon': 1, 'bags': 3, 'bandages': 1, 'bank': 5, 'banks': 2, 'banneshwar': 1, 'basic': 1, 'bbc': 1, 'bed': 2, 'begging': 2, 'betadine': 1, 'better': 1, 'bhaktapur': 1, 'bible': 1, 'bicc': 2, 'big': 3, 'bir': 1, 'birth': 1, 'biscuits': 3, 'bl': 1, 'blanket': 2, 'blankets': 5, 'blood': 44, 'blooddonation': 1, 'bloods': 1, 'body': 4, 'borne': 1, 'bottled': 1, 'bottles': 2, 'breaking': 1, 'brethren': 1, 'bridges': 1, 'brother': 1, 'brothers': 1, 'bucks': 1, 'bullshit': 1, 'buses': 2, 'calling': 1, 'cam': 1, 'came': 1, 'camp': 1, 'camps': 2, 'capacity': 1, 'capital': 2, 'cardiothoracic': 2, 'cards': 1, 'care': 5, 'case': 1, 'center': 1, 'central': 1, 'centre': 1, 'certain': 2, 'channels': 2, 'check': 1, 'children': 5, 'chowk': 1, 'churches': 1, 'cities': 1, 'citizens': 3, 'city': 1, 'classic': 1, 'clean': 5, 'clearly': 1, 'click': 1, 'clothes': 4, 'cold': 2, 'collapse': 1, 'colleagues': 1, 'collecting': 1, 'college': 1, 'colleges': 1, 'coming': 2, 'command': 1, 'commodities': 2, 'communication': 1, 'community': 2, 'compensation': 1, 'compensations': 1, 'complain': 1, 'condition': 1, 'conduct': 1, 'connectivity': 1, 'contact': 2, 'continuing': 1, 'contribute': 2, 'contribution': 1, 'coordination': 1, 'cope': 3, 'country': 3, 'create': 1, 'creature': 1, 'crimes': 1, 'crisis': 4, 'crore': 1, 'cross': 6, 'cure': 1, 'cut': 2, 'cylinders': 1, 'dam': 1, 'damage': 2, 'damaged': 4, 'dead': 3, 'dear': 3, 'death': 1, 'debris': 2, 'decided': 1, 'decimated': 1, 'deficiency': 1, 'delicate': 1, 'deliver': 1, 'deployment': 1, 'despair': 1, 'despatch': 1, 'desperate': 2, 'deupur': 1, 'devastated': 1, 'dhadagaun': 1, 'die': 2, 'died': 1, 'directly': 1, 'disaster': 2, 'diseases': 1, 'displaced': 2, 'distress': 1, 'distribution': 1, 'district': 1, 'dixit': 1, 'doctor': 3, 'doctors': 5, 'doesn': 2, 'dollars': 2, 'donate': 19, 'donateblood': 1, 'donated': 1, 'donating': 2, 'donation': 5, 'donations': 3, 'donors': 2, 'dont': 2, 'dr': 4, 'dried': 1, 'drink': 1, 'drinkable': 1, 'drinking': 6, 'drinks': 1, 'dropping': 1, 'drugs': 2, 'dry': 3, 'dug': 1, 'dying': 2, 'earliest': 1, 'earth': 3, 'earthquak': 4, 'earthquake': 72, 'earthquakeagain': 1, 'earthquakerelief': 1, 'eat': 1, 'eed': 1, 'effected': 2, 'efforts': 1, 'electric': 1, 'electricity': 6, 'embassy': 1, 'emergency': 4, 'epicenter': 1, 'equipment': 2, 'essential': 2, 'evacuate': 1, 'event': 1, 'everybody': 1, 'everyth': 1, 'expertise': 1, 'face': 3, 'facilitate': 1, 'facilities': 2, 'facing': 1, 'families': 3, 'fans': 1, 'farmers': 1, 'fast': 1, 'fear': 2, 'fears': 1, 'field': 2, 'fight': 1, 'filling': 1, 'fin': 1, 'finmin': 1, 'fixed': 2, 'flattened': 1, 'flight': 1, 'focusing': 2, 'followback': 1, 'following': 1, 'food': 83, 'foods': 4, 'forced': 1, 'forces': 1, 'form': 1, 'fr': 1, 'free': 1, 'friend': 1, 'friends': 1, 'frm': 1, 'fuel': 5, 'funds': 1, 'gairibisauna': 1, 'gandaki': 3, 'generator': 1, 'generous': 2, 'getting': 1, 'glad': 1, 'going': 1, 'gone': 1, 'gorkha': 4, 'gospel': 1, 'got': 1, 'government': 2, 'govt': 2, 'great': 2, 'grid': 1, 'grnd': 1, 'ground': 2, 'gt': 1, 'haphazard': 1, 'hasn': 1, 'having': 1, 'health': 2, 'hear': 1, 'heavy': 3, 'helicopters': 1, 'help': 47, 'helpful': 2, 'helping': 1, 'helpnepal': 3, 'hepters': 1, 'high': 1, 'hit': 4, 'hm': 1, 'hmrd': 1, 'hodgson': 1, 'homeless': 1, 'homes': 3, 'hope': 4, ' ...

# %%
df_2=(df.groupby('TweetClass')['TweetText'].apply(lambda x: np.mean(x.str.len())).reset_index(name='mean_characters_per_tweet'))
print(df_2)
# Out:
#    TweetClass  mean_characters_per_tweet
# 0           0                  91.662231
# 1           1                  98.798995
# 2           2                 102.626506

# %%
df_3=(df.groupby('TweetClass')['TweetText'].apply(lambda x: np.sum(x.str.len())).reset_index(name='sum_characters_all_tweets'))
print(df_3)
# Out:
#    TweetClass  sum_characters_all_tweets
# 0           0                  1591348.0
# 1           1                    19661.0
# 2           2                    68144.0

# %%
#Splitting the dataset into train and test parts using STRATIFIED SHUFFLE SPLIT technique.
x=new_df['TweetText']
y=new_df['TweetClass']
from sklearn.model_selection import train_test_split
tts=train_test_split(x,y,train_size=0.7,test_size=0.3,random_state=6,stratify=y)
x_train,x_test,y_train,y_test=tts

# %%
#Using TfIdfVectoriser to vectorise the dataset.
from sklearn.feature_extraction.text import TfidfVectorizer
vectorizer_train=TfidfVectorizer(lowercase=True)
dtm_train=vectorizer_train.fit_transform(x_train.values.astype('U'))
dtm_test=vectorizer_train.transform(x_test.values.astype('U'))

# %% [markdown]
# # CLASSIFICATION OF DATA
#
# ### ----Training the model using the training set
# ### ----Testing the model on the test set
# ### ----Printing the following for each classification algorithm:
# #### 1.Accuracy Score
# #### 2.Confusion Matrix
# #### 3.Classification Report

# %% [markdown]
# # 1.> Logistic Regression

# %%
from sklearn.linear_model import LogisticRegression
import datetime
regressor=LogisticRegression()
tick = datetime.datetime.now()
regressor.fit(dtm_train,y_train)
tock = datetime.datetime.now()
lr_train_time = tock - tick
print( lr_train_time)
# Out:
# 0:00:00.263433

# %%
tick = datetime.datetime.now()
y_pred_lr=regressor.predict(dtm_test)
tock = datetime.datetime.now()
lr_pred_time = tock - tick
print( lr_pred_time)
# Out:
# 0:00:00.002997

# %%
from sklearn.metrics import confusion_matrix , classification_report , accuracy_score

# %%
score1=accuracy_score(y_test,y_pred_lr)
print(score1)
#Observe accuracy 96.28%.
# Out:
# 0.9628884826325411

# %%
print(confusion_matrix(y_test,y_pred_lr))
# Out:
# [[5193    1   17]
#  [  54    4    2]
#  [ 129    0   70]]

# %%
print(classification_report(y_test,y_pred_lr))
# Out:
#              precision    recall  f1-score   support
#
#           0       0.97      1.00      0.98      5211
#           1       0.80      0.07      0.12        60
#           2       0.79      0.35      0.49       199
#
# avg / total       0.96      0.96      0.95      5470

# %% [markdown]
# # 2> KNN

# %%
from sklearn.neighbors import KNeighborsClassifier
knn=KNeighborsClassifier(n_neighbors=3)
tick = datetime.datetime.now()
knn.fit(dtm_train,y_train)
tock = datetime.datetime.now()
knn_train_time = tock - tick
print( knn_train_time)
# Out:
# 0:00:00.005309

# %%
tick = datetime.datetime.now()
y_pred_knn=knn.predict(dtm_test)
tock = datetime.datetime.now()
knn_pred_time = tock - tick
print( knn_pred_time)
# Out:
# 0:00:05.073065

# %%
score2=accuracy_score(y_test,y_pred_knn)
print(score2)
#Observe accuracy 96.58%.
# Out:
# 0.9667276051188299

# %%
print(confusion_matrix(y_test,y_pred_knn))
# Out:
# [[5154    2   55]
#  [  42   16    2]
#  [  77    4  118]]

# %%
print(classification_report(y_test,y_pred_knn))
# Out:
#              precision    recall  f1-score   support
#
#           0       0.98      0.99      0.98      5211
#           1       0.73      0.27      0.39        60
#           2       0.67      0.59      0.63       199
#
# avg / total       0.96      0.97      0.96      5470

# %% [markdown]
# # 3> Multinomial Naive Bayes

# %%
from sklearn.naive_bayes import MultinomialNB
model1 = MultinomialNB()
tick = datetime.datetime.now()
model1.fit(dtm_train, y_train)
tock = datetime.datetime.now()
nb_train_time = tock - tick
print( nb_train_time)
# Out:
# 0:00:00.007975

# %%
tick = datetime.datetime.now()
y_pred_nvm= model1.predict(dtm_test)
tock = datetime.datetime.now()
nb_pred_time = tock - tick
print( nb_pred_time)
# Out:
# 0:00:00.002360

# %%
score3=accuracy_score(y_test , y_pred_nvm)
print(score3)
#Observe accuracy 95.33%.
# Out:
# 0.953382084095064

# %%
print(confusion_matrix(y_test,y_pred_nvm))
# Out:
# [[5208    0    3]
#  [  60    0    0]
#  [ 192    0    7]]

# %%
print(classification_report(y_test,y_pred_nvm))
# Out:
#              precision    recall  f1-score   support
#
#           0       0.95      1.00      0.98      5211
#           1       0.00      0.00      0.00        60
#           2       0.70      0.04      0.07       199
#
# avg / total       0.93      0.95      0.93      5470
# C:\Users\Nishant\Anaconda3\lib\site-packages\sklearn\metrics\classification.py:1135: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)

# %%
import pandas as pd
import seaborn as sns

Accuracy = [score1,score2,score3]  


Train_time = [lr_train_time,knn_train_time,nb_train_time]
pred_test_time = [lr_pred_time,knn_pred_time,nb_pred_time]

data = { 'Accuracy' : Accuracy,
         'Train_Time': Train_time,
         'Prediction': pred_test_time,
         'Algorithm': ['Logistic Regression','KNeighbors',"Naive Baye's"]}

df = pd.DataFrame( data)

# %% [markdown]
# # Comparison based on Accuracy

# %%
sns.barplot(x = df.Accuracy, y = df.Algorithm)

# %% [markdown]
# # Comparison Based on Training Time

# %%
sns.barplot(x = df.Train_Time, y = df.Algorithm)

# %% [markdown]
# # Comparison Based on Prediction Time

# %%
sns.barplot(x = df.Prediction, y = df.Algorithm)
