# %%
import pandas as pd 
import numpy as np              
import seaborn as sns           
import matplotlib.pyplot as plt

# %%
df=pd.read_csv("train.csv")

# %%
df.head(20)
# Out:
#     TweetClass             TweetID  \
# 0            0  591764470197723137
# 1            0  591779538046218240
# 2            0  591728244925210624
# 3            0  591774433926193152
# 4            0  591764472651386882
# 5            0  591751543025569793
# 6            0  591727216267890688
# 7            0  591739000001470464
# 8            0  591753691084038146
# 9            0  591747428358881282
# 10           0  591760691872169985
# 11           0  591770916360560640
# 12           0  591751403221098496
# 13           0  591726847219478528
# 14           0  591714830446301184
# 15           0  591732037159030785
# 16           0  591672103788621824
# 17           0  591673483832270848
# 18           0  591729367132188672
# 19           0  591746927269523458
#
#                                             TweetText
# 0   #Nepal #news Adding to Bhutanese Refugees Bhut...
# 1   The massacre of people's movement says peace a...
# ...

# %%
df.shape
# Out:
# (4238, 3)

# %%
df.describe()
# Out:
#        TweetClass       TweetID
# count      4238.0  4.238000e+03
# mean          0.0  5.919338e+17
# std           0.0  8.145368e+13
# min           0.0  5.916721e+17
# 25%           0.0  5.918709e+17
# 50%           0.0  5.919156e+17
# 75%           0.0  5.919930e+17
# max           0.0  5.921537e+17

# %%
print(df.keys())
# Out:
# Index(['TweetClass', 'TweetID', 'TweetText'], dtype='object')
